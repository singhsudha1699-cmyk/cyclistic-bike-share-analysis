# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.3

# %%
df_2019 = pd.read_csv("data/Divvy_Trips_2019_Q1 - Divvy_Trips_2019_Q1.csv")

# %%
df_2020 = pd.read_csv("data/Divvy_Trips_2020_Q1 - Divvy_Trips_2020_Q1.csv")

# %%
df_2019.head()
# Out:
#     trip_id          start_time            end_time  bikeid tripduration  \
# 0  21742443  2019-01-01 0:04:37  2019-01-01 0:11:07    2167          390
# 1  21742444  2019-01-01 0:08:13  2019-01-01 0:15:34    4386          441
# 2  21742445  2019-01-01 0:13:23  2019-01-01 0:27:12    1524          829
# 3  21742446  2019-01-01 0:13:45  2019-01-01 0:43:28     252     1,783.00
# 4  21742447  2019-01-01 0:14:52  2019-01-01 0:20:56    1170          364
#
#    from_station_id                    from_station_name  to_station_id  \
# 0              199               Wabash Ave & Grand Ave             84
# 1               44               State St & Randolph St            624
# 2               15                 Racine Ave & 18th St            644
# 3              123       California Ave & Milwaukee Ave            176
# 4              173  Mies van der Rohe Way & Chicago Ave             35
#
#                   to_station_name    usertype  gender  birthyear
# ...

# %%
df_2020.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  EACB19130B0CDA4A   docked_bike  2020-01-21 20:06:59  2020-01-21 20:14:30
# 1  8FED874C809DC021   docked_bike  2020-01-30 14:22:39  2020-01-30 14:26:22
# 2  789F3C21E472CA96   docked_bike  2020-01-09 19:29:26  2020-01-09 19:32:17
# 3  C9A388DAC6ABF313   docked_bike  2020-01-06 16:17:07  2020-01-06 16:25:56
# 4  943BC3CBECCFD662   docked_bike   2020-01-30 8:37:16   2020-01-30 8:42:48
#
#          start_station_name  start_station_id                end_station_name  \
# 0  Western Ave & Leland Ave               239           Clark St & Leland Ave
# 1   Clark St & Montrose Ave               234  Southport Ave & Irving Park Rd
# 2    Broadway & Belmont Ave               296        Wilton Ave & Belmont Ave
# 3    Clark St & Randolph St                51        Fairbanks Ct & Grand Ave
# 4      Clinton St & Lake St                66           Wells St & Hubbard St
#
# ...

# %%
df_2019.shape
# Out:
# (365069, 12)

# %%
df_2020.shape
# Out:
# (426887, 13)

# %%
df_2019.columns
# Out:
# Index(['trip_id', 'start_time', 'end_time', 'bikeid', 'tripduration',
#        'from_station_id', 'from_station_name', 'to_station_id',
#        'to_station_name', 'usertype', 'gender', 'birthyear'],
#       dtype='object')

# %%
df_2020.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='object')

# %%
df_2019 = df_2019.rename(columns={
    'trip_id': 'ride_id',
    'start_time': 'started_at',
    'end_time' : 'ended_at',
    'from_station_name' : 'start_station_name',
    'from_station_id' : 'start_station_id',
    'to_station_name' : 'end_station_name',
    'to_station_id' : 'end_station_id',
    'usertype' : 'member_casual'
})

# %%
df_2019.columns
# Out:
# Index(['ride_id', 'started_at', 'ended_at', 'bikeid', 'tripduration',
#        'start_station_id', 'start_station_name', 'end_station_id',
#        'end_station_name', 'member_casual', 'gender', 'birthyear'],
#       dtype='object')

# %%
df_2019['member_casual'].value_counts()
# Out:
# member_casual
# Subscriber    341906
# Customer       23163
# Name: count, dtype: int64

# %%
df_2019['member_casual'] = df_2019['member_casual'].replace({
    'Subscriber' : 'member',
    'Customer':'casual'
})

# %%
 df_2019['member_casual'].value_counts()
# Out:
# member_casual
# member    341906
# casual     23163
# Name: count, dtype: int64

# %%
df_2020['member_casual'].value_counts()
# Out:
# member_casual
# member    378407
# casual     48480
# Name: count, dtype: int64

# %%
df_2019[['started_at', 'ended_at']].dtypes
# Out:
# started_at    object
# ended_at      object
# dtype: object

# %%
df_2020[['started_at','ended_at']].dtypes
# Out:
# started_at    object
# ended_at      object
# dtype: object

# %%
df_2019['started_at'] = pd.to_datetime(df_2019['started_at'])
df_2019['ended_at'] = pd.to_datetime(df_2019['ended_at'])

# %%
df_2020['started_at'] = pd.to_datetime(df_2020['started_at'])
df_2020['ended_at'] = pd.to_datetime(df_2020['ended_at'])

# %%
df_2019[['started_at', 'ended_at']].dtypes
# Out:
# started_at    datetime64[ns]
# ended_at      datetime64[ns]
# dtype: object

# %%
df_2020[['started_at', 'ended_at']].dtypes
# Out:
# started_at    datetime64[ns]
# ended_at      datetime64[ns]
# dtype: object

# %%
df_2019['ride_length'] = df_2019['ended_at'] - df_2019['started_at']

# %%
df_2019[['started_at', 'ended_at', 'ride_length']].head()
# Out:
#            started_at            ended_at     ride_length
# 0 2019-01-01 00:04:37 2019-01-01 00:11:07 0 days 00:06:30
# 1 2019-01-01 00:08:13 2019-01-01 00:15:34 0 days 00:07:21
# 2 2019-01-01 00:13:23 2019-01-01 00:27:12 0 days 00:13:49
# 3 2019-01-01 00:13:45 2019-01-01 00:43:28 0 days 00:29:43
# 4 2019-01-01 00:14:52 2019-01-01 00:20:56 0 days 00:06:04

# %%
df_2020['ride_length'] = df_2020['ended_at'] - df_2020['started_at']

# %%
df_2020[['started_at', 'ended_at', 'ride_length']].head()
# Out:
#   started_at ended_at ride_length
# 0        NaT      NaT         NaT
# 1        NaT      NaT         NaT
# 2        NaT      NaT         NaT
# 3        NaT      NaT         NaT
# 4        NaT      NaT         NaT

# %%
(df_2019['ride_length'] < pd.Timedelta(0)).sum()
# Out:
# np.int64(0)

# %%
(df_2020['ride_length'] < pd.Timedelta(0)).sum()
# Out:
# np.int64(0)

# %%
(df_2019['ride_length'] == pd.Timedelta(0)).sum()
# Out:
# np.int64(0)

# %%
(df_2020['ride_length'] == pd.Timedelta(0)).sum()
# Out:
# np.int64(0)

# %%
df_2020[df_2020['ride_length'] <= pd.Timedelta(0)][
    ['ride_id', 'started_at', 'ended_at', 'ride_length', 'member_casual']
].head(10)
# Out:
# Empty DataFrame
# Columns: [ride_id, started_at, ended_at, ride_length, member_casual]
# Index: []

# %%
df_2020 = df_2020[df_2020['ride_length'] > pd.Timedelta(0)]

# %%
(df_2020['ride_length'] <= pd.Timedelta(0)).sum()
# Out:
# np.int64(0)

# %%
df_2019['day_of_week'] = df_2019['started_at'].dt.dayofweek

# %%
df_2020['day_of_week'] = df_2020['started_at'].dt.dayofweek

# %%
df_2019[['started_at', 'day_of_week']].head()
# Out:
#            started_at  day_of_week
# 0 2019-01-01 00:04:37            1
# 1 2019-01-01 00:08:13            1
# 2 2019-01-01 00:13:23            1
# 3 2019-01-01 00:13:45            1
# 4 2019-01-01 00:14:52            1

# %%
df_2020[['started_at', 'day_of_week']].head()
# Out:
# Empty DataFrame
# Columns: [started_at, day_of_week]
# Index: []

# %%
df_2019.isnull().sum()
# Out:
# ride_id                   0
# started_at                0
# ended_at                  0
# bikeid                    0
# tripduration              0
# start_station_id          0
# start_station_name        0
# end_station_id            0
# end_station_name          0
# member_casual             0
# gender                19711
# birthyear             18023
# ride_length               0
# day_of_week               0
# dtype: int64
